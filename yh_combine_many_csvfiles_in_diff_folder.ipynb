# %%
import pandas as pd
import os
dflist=[]
for f in os.listdir('d:/lvr_data2'):
    path = 'd:/lvr_data2/{}/A_lvr_land_b.CSV'
    # print(path.format(f))
    df = pd.read_csv(path.format(f))
    dflist.append(df)

# %%
len(dflist)
# Out:
# 4

# %%
dfall = pd.concat(dflist)

# %%
dfall.head()
# Out:
#                                     鄉鎮市區              交易標的  \
# 0  The villages and towns urban district  transaction sign
# 1                                    文山區         房地(土地+建物)
# 2                                    中正區         房地(土地+建物)
# 3                                    文山區         房地(土地+建物)
# 4                                    文山區                車位
#
#                                         土地區段位置建物區段門牌  \
# 0  land sector position building sector house num...
# 1                             臺北市文山區興隆路三段185巷5弄1~30號
# 2                               臺北市中正區羅斯福路四段12巷1~30號
# 3                                   臺北市文山區久康街91~120號
# 4                               臺北市文山區辛亥路四段252巷1~30號
#
#                              土地移轉總面積平方公尺  \
# 0  land shifting total area square meter
# 1                                  37.79
# 2                                  27.92
# 3                                   29.4
# 4                                   1.51
#
# ...

# %%
dfall.describe()
# Out:
#         鄉鎮市區          交易標的     土地區段位置建物區段門牌 土地移轉總面積平方公尺 都市土地使用分區  \
# count   1125          1125             1125        1125     1125
# unique    11             4               48         327        4
# top      中山區  房地(土地+建物)+車位  公訓段二小段571~600地號        3.13        住
# freq     198           867               97          27      760
#
#                                    非都市土地使用分區                非都市土地使用編定  \
# count                                      4                        4
# unique                                     1                        1
# top     the non-metropolis land use district  non-metropolis land use
# freq                                       4                        4
#
#           交易年月日      交易筆棟數  移轉層次  ... 建物現況格局-衛 建物現況格局-隔間 有無管理組織      總價元  \
# count      1125       1125  1111  ...     1125      1125   1125     1125
# unique      645         28    27  ...        5         3      2      846
# ...
